# %%
import pandas as pd

# %%
df =  pd.read_csv("all_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119767 entries, 0 to 4119766
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   episode     int64
#  1   time        float64
#  2   agent_type  object
#  3   agent_id    int64
#  4   x           float64
#  5   y           float64
#  6   theta       float64
#  7   vx          float64
#  8   vy          float64
#  9   u_v         float64
#  10  u_omega     float64
#  11  goal_x      float64
#  12  goal_y      float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 408.6+ MB

# %%
df.iloc[-1]
# Out:
# episode             6180
# time                3.73
# agent_type    pedestrian
# agent_id              10
# x               0.595735
# y              -0.700094
# theta          -0.856218
# vx              0.570204
# vy             -0.125979
# u_v                  NaN
# u_omega              NaN
# goal_x               NaN
# goal_y               NaN
# Name: 4119766, dtype: object
